# %%
# set the project path
# %cd ~/projects/drug-pricing
# Out:
# /home/denhart.c/projects/drug-pricing

# %%
# %load_ext autoreload

# %%
# %autoreload 2

import os
import pickle
from datetime import datetime
from tqdm import tqdm
from bson.objectid import ObjectId
from collections import Counter

import pandas as pd

from src.utils import connect_to_mongo, get_nlp, ROOT_DIR, get_praw
from src.schema import Post, User

# %%
connect_to_mongo()

# %%
lockdown_dt = datetime(2020, 3, 1)
max_dt = datetime.now()
min_dt = lockdown_dt - (max_dt - lockdown_dt)

# %%
def get_user_month_counts() -> pd.DataFrame:
	pipeline = [
		{
			"$group": {
				"_id": { "year": {"$year": "$datetime"}, "month": {"$month": "$datetime"}, "user": "$user"},
				"num_datetimes": {"$sum": {"$cond": { "if": { "$ne": ["$datetime","true"] },"then": 1,"else": 0 }}},
				"num_spacy": {"$sum": {"$cond": { "if": { "$ne": ["$spacy","true"] },"then": 1,"else": 0 }}},
				"num_posts": {"$sum": 1},
			}
		},
        { 
            '$lookup': {
				'from': 'users',
				'localField': 'user',
				'foreignField': '_id',
				'as': 'userData'
			}
		},
	]
	month_counts = Post.objects(subreddit='opiates').limit(10).aggregate(pipeline)
	'''
	rows = [{'datetime': datetime(r['_id']['year'], r['_id']['month'], 1),
			'num_datetimes': r['num_datetimes'],
			'num_spacy': r['num_spacy'],
			'num_posts': r['num_posts']
			} for r in res if (r['_id']['year'] and r['_id']['month'])]
	df = pd.DataFrame(rows)
	return df
	'''
	res = list(month_counts)
	return res

# %%
res = get_user_month_counts()

# %%
p1 = User.objects(pk='6154445924dd76f5e6e3cc80')

# %%
p1
# Out:
# [<User: TheThermalCoyote13>]

# %%
ids = [str(r['_id']['user']) if 'user' in r['_id'] else None for r in res]

# %%
usernames = [User.objects(pk=_id).only('username').first().username if _id else None for _id in ids]

# %%
usernames
# Out:
# ['rougekhmero',
#  'TheThermalCoyote13',
#  None,
#  'konsept503pdx',
#  'BenzosOpiatesAll420',
#  'AutoModerator',
#  '593365',
#  'opals-and-banonos']

# %%
len(ids)
# Out:
# 8

# %%
for r in res:
    print(r['_id']['user'])
# Out:
# 5f27a5024c07ca09ea1b032a
# 6154445924dd76f5e6e3cc80
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-eb6a5a9a12eb> in <module>
#       1 for r in res:
# ----> 2     print(r['_id']['user'])
#
# KeyError: 'user'

# %%
res
# Out:
# [{'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('5f27a5024c07ca09ea1b032a')},
#   'num_datetimes': 1,
#   'num_spacy': 1,
#   'num_posts': 1,
#   'userData': []},
#  {'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('6154445924dd76f5e6e3cc80')},
#   'num_datetimes': 1,
#   'num_spacy': 1,
#   'num_posts': 1,
#   'userData': []},
#  {'_id': {'year': 2021, 'month': 9},
#   'num_datetimes': 2,
#   'num_spacy': 2,
#   'num_posts': 2,
#   'userData': []},
#  {'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('6154445924dd76f5e6e3cc7f')},
#   'num_datetimes': 1,
#   'num_spacy': 1,
#   'num_posts': 1,
#   'userData': []},
#  {'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('613a9284e775717b4d75522f')},
#   'num_datetimes': 1,
#   'num_spacy': 1,
#   'num_posts': 1,
#   'userData': []},
#  {'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('5f2636a84c07ca09eabbd64d')},
#   'num_datetimes': 1,
#   'num_spacy': 1,
#   'num_posts': 1,
#   'userData': []},
#  {'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('6154445924dd76f5e6e3cc7e')},
#   'num_datetimes': 2,
#   'num_spacy': 2,
#   'num_posts': 2,
#   'userData': []},
#  {'_id': {'year': 2021,
#    'month': 9,
#    'user': ObjectId('5fac418c8096959e95a05cb1')},
#   'num_datetimes': 1,
#   'num_spacy': 1,
#   'num_posts': 1,
#   'userData': []}]

# %%
covid_cache_fp = '/work/akilby/drug_pricing_project/denhart_cache/covid_keyword_counts_cache_opiates_1634766740.pk'
with open(covid_cache_fp, 'rb') as f:
    covid_cache = pickle.load(f)

# %%
months_users_fp = '/work/akilby/drug_pricing_project/denhart_cache/opiates_month_user_counts_2021-10-14 08:08:02.963907.pk'
with open(months_users_fp, 'rb') as f:
    month_users_counts = pickle.load(f)

# %%
len(month_users_counts)
# Out:
# 359409

# %%
month_users_counts
# Out:
# [('keepitcasualbrah',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdeae')},
#    'num_datetimes': 38,
#    'num_spacy': 38,
#    'num_posts': 38}),
#  ('tripsick',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdebe')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Adix1',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdec0')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('stelllaaaa',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdecd')},
#    'num_datetimes': 24,
#    'num_spacy': 24,
#    'num_posts': 24}),
#  ('aAscii',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdef1')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('PMMeYourBootyPics',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdef7')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('wishy_wash',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01dbf4b80e41dacdf02')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Nittanybro',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdf6c')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('qlopithrowaway',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdf75')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('dfghjksds',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdf7a')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('portcitydoper910',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdf7d')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('Break_My_Fall',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdf8c')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('nomorescore',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdf97')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('greenbabyshit',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdfb8')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Lbliss08',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdfc8')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('FentanylHcl',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01ebf4b80e41dacdfeb')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('freddie_gibbs',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace000')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('TrynaMoveThatDope',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace002')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Sheerekhan',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace004')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('creatorofcreators',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace01a')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('TryingBTHfirstTime',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace02b')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('suboxonethrowaway',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace02e')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('justfortoday420',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace03d')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('STandAgainst',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace043')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('huskygeezer',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace049')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('guywithcancernotcool',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace069')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('BigDaddyHotdogDick',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace06d')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Clarkmen101',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace07a')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('lolacarmenlisterine',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace07f')},
#    'num_datetimes': 15,
#    'num_spacy': 15,
#    'num_posts': 15}),
#  ('PopeZen',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e01fbf4b80e41dace085')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('philadelphiamuc',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace0b1')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('RoyalOil39',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace0ba')},
#    'num_datetimes': 14,
#    'num_spacy': 14,
#    'num_posts': 14}),
#  ('liberachi462606',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace0bf')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Harlingen',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace0c4')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('adminsblo',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace0f5')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('billlansdowne',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace109')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('BrrRva',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace11d')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('simple-pickup',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e020bf4b80e41dace12f')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('tantalized',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace15e')},
#    'num_datetimes': 32,
#    'num_spacy': 32,
#    'num_posts': 32}),
#  ('default_username29',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace18b')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('AcesHiii',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace1a3')},
#    'num_datetimes': 75,
#    'num_spacy': 75,
#    'num_posts': 75}),
#  ('nodz',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace1cd')},
#    'num_datetimes': 280,
#    'num_spacy': 280,
#    'num_posts': 280}),
#  ('DINGwhen_theresSTUFF',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace1da')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('dopestoriesthrowaway',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace1e6')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Txmedic',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace1ef')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('sweetsinner69',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace207')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('BeastLicker',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e021bf4b80e41dace20d')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('NodShady',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace217')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('Thatwarmblanket',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace228')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('PLEASE_UPVOTE_ME_',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace230')},
#    'num_datetimes': 10,
#    'num_spacy': 10,
#    'num_posts': 10}),
#  ('mango-mang',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace23f')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('MsPacMansPills',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace250')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('inthenameofsuffering',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace25f')},
#    'num_datetimes': 31,
#    'num_spacy': 31,
#    'num_posts': 31}),
#  ('LiftdFUZZbapp',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace273')},
#    'num_datetimes': 45,
#    'num_spacy': 45,
#    'num_posts': 45}),
#  ('throwawaybumbee',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace27a')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('iselfpollinate',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace286')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('Deathraged',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace29d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('draway22',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace2ae')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Javi2639',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace2b7')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('Sadchop',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace2c6')},
#    'num_datetimes': 61,
#    'num_spacy': 61,
#    'num_posts': 61}),
#  ('Killyourselfirst',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e022bf4b80e41dace2cf')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('Osama_Bin_Noddin',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e023bf4b80e41dace2eb')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('doubleyouseven',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e023bf4b80e41dace313')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('SubutexSniffer',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e023bf4b80e41dace318')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Ketamax',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e023bf4b80e41dace33d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('CPn0dCP',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e023bf4b80e41dace357')},
#    'num_datetimes': 56,
#    'num_spacy': 56,
#    'num_posts': 56}),
#  ('tonezc',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e023bf4b80e41dace35a')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('noussr',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace38a')},
#    'num_datetimes': 1109,
#    'num_spacy': 1109,
#    'num_posts': 1109}),
#  ('Watch_Donkey',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace39b')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('weirddrugs',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace3ab')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('508browntown',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace3b9')},
#    'num_datetimes': 13,
#    'num_spacy': 13,
#    'num_posts': 13}),
#  ('dred1981',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace3be')},
#    'num_datetimes': 52,
#    'num_spacy': 52,
#    'num_posts': 52}),
#  ('shadowchronic',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace3e2')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('Kingblunt204',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace3f3')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Beatlsam1973',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace40b')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('safooma',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e024bf4b80e41dace421')},
#    'num_datetimes': 12,
#    'num_spacy': 12,
#    'num_posts': 12}),
#  ('rem12377',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e025bf4b80e41dace439')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('AddictedToAwesome',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e025bf4b80e41dace442')},
#    'num_datetimes': 11,
#    'num_spacy': 11,
#    'num_posts': 11}),
#  ('PheonixSummersault',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e025bf4b80e41dace456')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Kalpril',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e025bf4b80e41dace4b4')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('drinkmydespair2',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e025bf4b80e41dace4cd')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Mofroulis',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace4d7')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Errorticandlazy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace4e9')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('curiousaboutdrugs',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace4ef')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('rickthespic',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace4f7')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('abbyrd',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace4fe')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('afrinpack',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace503')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('arto2',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace524')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('GuntripAnalysis',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace530')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('RiggyTiggyTavvy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace539')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('illme',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e026bf4b80e41dace581')},
#    'num_datetimes': 42,
#    'num_spacy': 42,
#    'num_posts': 42}),
#  ('Deckapuss',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e027bf4b80e41dace5a1')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('IThinkImDumb',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e734bf4b80e41db10f1f')},
#    'num_datetimes': 25,
#    'num_spacy': 25,
#    'num_posts': 25}),
#  ('fubbington',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e73dbf4b80e41db11665')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('ThaGarden',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e73dbf4b80e41db1167b')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('CFRiver',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e73ebf4b80e41db116a7')},
#    'num_datetimes': 18,
#    'num_spacy': 18,
#    'num_posts': 18}),
#  ('JimiThing716',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e73ebf4b80e41db116c0')},
#    'num_datetimes': 35,
#    'num_spacy': 35,
#    'num_posts': 35}),
#  ('bayou_billy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e73ebf4b80e41db116dd')},
#    'num_datetimes': 12,
#    'num_spacy': 12,
#    'num_posts': 12}),
#  ('yigdish',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e741bf4b80e41db118d3')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Weezsti',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e741bf4b80e41db118da')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Morfz',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e741bf4b80e41db11937')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('asbyo',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e742bf4b80e41db11a03')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('zipthalip1243',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e742bf4b80e41db11a31')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Bruins37FTW',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e742bf4b80e41db11a40')},
#    'num_datetimes': 122,
#    'num_spacy': 122,
#    'num_posts': 122}),
#  ('MangoBatman',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e743bf4b80e41db11a5a')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('1etsstartover',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e743bf4b80e41db11add')},
#    'num_datetimes': 10,
#    'num_spacy': 10,
#    'num_posts': 10}),
#  ('an_unexpected_boner',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e745bf4b80e41db11bbf')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('TheHappyWhale',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e745bf4b80e41db11bce')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('heremeoutt',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e745bf4b80e41db11bed')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('rickyrawesome',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e74ebf4b80e41db121ee')},
#    'num_datetimes': 193,
#    'num_spacy': 193,
#    'num_posts': 193}),
#  ('trackerundertow',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e74ebf4b80e41db12204')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('pantsboy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e74ebf4b80e41db1227b')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('dtrain4870',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e74ebf4b80e41db1227f')},
#    'num_datetimes': 11,
#    'num_spacy': 11,
#    'num_posts': 11}),
#  ('thecheifingpanda',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e74ebf4b80e41db12283')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('SoberRanger30',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e74ebf4b80e41db12285')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('woodenpipe',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e751bf4b80e41db12455')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('TheBigTimer',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e751bf4b80e41db1247a')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('FatManManFat',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e752bf4b80e41db1249c')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('DerangedFluff',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e752bf4b80e41db1251d')},
#    'num_datetimes': 66,
#    'num_spacy': 66,
#    'num_posts': 66}),
#  ('Johnny_Walker_Red',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e752bf4b80e41db12537')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('master721',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e754bf4b80e41db1261f')},
#    'num_datetimes': 38,
#    'num_spacy': 38,
#    'num_posts': 38}),
#  ('casualrayet',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e756bf4b80e41db12766')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('originalironicname',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e756bf4b80e41db1276c')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('___diamond',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e759bf4b80e41db12953')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('DeepInTheRabbitHole',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e759bf4b80e41db1295a')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('Kalvynn',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e759bf4b80e41db12961')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('grievous2552',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e75abf4b80e41db12a4f')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('collinfc',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e75abf4b80e41db12a52')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('wfarber1',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e75abf4b80e41db12a69')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('NahM8uR',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e75cbf4b80e41db12b58')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('sarabellam',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e75cbf4b80e41db12bc6')},
#    'num_datetimes': 15,
#    'num_spacy': 15,
#    'num_posts': 15}),
#  ('hamonz123',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e761bf4b80e41db12f8e')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('sodappop',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e761bf4b80e41db12fa0')},
#    'num_datetimes': 764,
#    'num_spacy': 764,
#    'num_posts': 764}),
#  ('boxcarauman',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e762bf4b80e41db13012')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('theruss0n',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e762bf4b80e41db13019')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Territomauvais',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e763bf4b80e41db1305d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('MBsurfMD',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e763bf4b80e41db1306a')},
#    'num_datetimes': 12,
#    'num_spacy': 12,
#    'num_posts': 12}),
#  ('Derp_Simulator',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76abf4b80e41db134fd')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('colourhazed',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76abf4b80e41db1355d')},
#    'num_datetimes': 18,
#    'num_spacy': 18,
#    'num_posts': 18}),
#  ('kricket53',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76abf4b80e41db1358e')},
#    'num_datetimes': 71,
#    'num_spacy': 71,
#    'num_posts': 71}),
#  ('highmr',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76abf4b80e41db13590')},
#    'num_datetimes': 44,
#    'num_spacy': 44,
#    'num_posts': 44}),
#  ('multi_reality',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76bbf4b80e41db13602')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Unique_Name_2',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76bbf4b80e41db1361e')},
#    'num_datetimes': 330,
#    'num_spacy': 330,
#    'num_posts': 330}),
#  ('NovaEraMDM',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76cbf4b80e41db1373a')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('SeekingContentment',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76ebf4b80e41db137dd')},
#    'num_datetimes': 178,
#    'num_spacy': 178,
#    'num_posts': 178}),
#  ('elaborateruser',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76ebf4b80e41db13802')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('lagpwned',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76fbf4b80e41db13880')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('Shitjustgotshitty',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e76fbf4b80e41db13888')},
#    'num_datetimes': 16,
#    'num_spacy': 16,
#    'num_posts': 16}),
#  ('COBHC92',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e770bf4b80e41db13925')},
#    'num_datetimes': 19,
#    'num_spacy': 19,
#    'num_posts': 19}),
#  ('hamboneneurosis',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e771bf4b80e41db139e1')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('Wigginmiller',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e773bf4b80e41db13a66')},
#    'num_datetimes': 10,
#    'num_spacy': 10,
#    'num_posts': 10}),
#  ('cHalls',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e773bf4b80e41db13aa5')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('Pobie0622',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e773bf4b80e41db13ab1')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('era_extrana',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e774bf4b80e41db13af9')},
#    'num_datetimes': 52,
#    'num_spacy': 52,
#    'num_posts': 52}),
#  ('zeroblackzx',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e774bf4b80e41db13b19')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Blumkinpunkin',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e774bf4b80e41db13b53')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('xodannica',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13b83')},
#    'num_datetimes': 23,
#    'num_spacy': 23,
#    'num_posts': 23}),
#  ('vansprinkel',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13bb7')},
#    'num_datetimes': 313,
#    'num_spacy': 313,
#    'num_posts': 313}),
#  ('Stridez_21',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13bc1')},
#    'num_datetimes': 76,
#    'num_spacy': 76,
#    'num_posts': 76}),
#  ('rahtin',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13bdf')},
#    'num_datetimes': 53,
#    'num_spacy': 53,
#    'num_posts': 53}),
#  ('slackerjazz',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13bfe')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('elizavictoria',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13c01')},
#    'num_datetimes': 23,
#    'num_spacy': 23,
#    'num_posts': 23}),
#  ('gokuwayne721',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13c09')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('jakehopt',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e775bf4b80e41db13c0b')},
#    'num_datetimes': 166,
#    'num_spacy': 166,
#    'num_posts': 166}),
#  ('BestDrugAdvice',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c44')},
#    'num_datetimes': 415,
#    'num_spacy': 415,
#    'num_posts': 415}),
#  ('216216',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c56')},
#    'num_datetimes': 41,
#    'num_spacy': 41,
#    'num_posts': 41}),
#  ('Turdfart44',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c5c')},
#    'num_datetimes': 147,
#    'num_spacy': 147,
#    'num_posts': 147}),
#  ('igorwolf',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c5f')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('ritchiesrainbow',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c6a')},
#    'num_datetimes': 184,
#    'num_spacy': 184,
#    'num_posts': 184}),
#  ('Thepooperscooper',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c6f')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('HappyMan420',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13c90')},
#    'num_datetimes': 271,
#    'num_spacy': 271,
#    'num_posts': 271}),
#  ('whothisguy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13cbb')},
#    'num_datetimes': 11,
#    'num_spacy': 11,
#    'num_posts': 11}),
#  ('xtiaaneubaten',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e776bf4b80e41db13ccd')},
#    'num_datetimes': 218,
#    'num_spacy': 218,
#    'num_posts': 218}),
#  ('dar212',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13cdd')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('bc458',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13cf6')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('GrayIceWater',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d0c')},
#    'num_datetimes': 51,
#    'num_spacy': 51,
#    'num_posts': 51}),
#  ('Alli911',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d14')},
#    'num_datetimes': 256,
#    'num_spacy': 256,
#    'num_posts': 256}),
#  ('dopelessfopefiend',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d17')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('RapperOnDrugs',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d20')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('wicci',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d28')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('Slexx',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d33')},
#    'num_datetimes': 17,
#    'num_spacy': 17,
#    'num_posts': 17}),
#  ('sexfart',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d42')},
#    'num_datetimes': 68,
#    'num_spacy': 68,
#    'num_posts': 68}),
#  ('The_Kief_Chief',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e777bf4b80e41db13d7f')},
#    'num_datetimes': 52,
#    'num_spacy': 52,
#    'num_posts': 52}),
#  ('Muirlimgan',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e778bf4b80e41db13de9')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('The_Real_Doppelgange',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13e60')},
#    'num_datetimes': 1373,
#    'num_spacy': 1373,
#    'num_posts': 1373}),
#  ('__Clyde_Frog__',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13e73')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('CCG14',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13e79')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('makinlulz420',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13e90')},
#    'num_datetimes': 37,
#    'num_spacy': 37,
#    'num_posts': 37}),
#  ('Dr-Professor',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13e93')},
#    'num_datetimes': 69,
#    'num_spacy': 69,
#    'num_posts': 69}),
#  ('turd_boy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13ea8')},
#    'num_datetimes': 184,
#    'num_spacy': 184,
#    'num_posts': 184}),
#  ('Megan23247',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13ead')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('filonome',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13eb5')},
#    'num_datetimes': 116,
#    'num_spacy': 116,
#    'num_posts': 116}),
#  ('SethProff',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13eef')},
#    'num_datetimes': 38,
#    'num_spacy': 38,
#    'num_posts': 38}),
#  ('Magic_markers',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e779bf4b80e41db13f1c')},
#    'num_datetimes': 18,
#    'num_spacy': 18,
#    'num_posts': 18}),
#  ('dickobags',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f29')},
#    'num_datetimes': 21,
#    'num_spacy': 21,
#    'num_posts': 21}),
#  ('rollaway910',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f37')},
#    'num_datetimes': 12,
#    'num_spacy': 12,
#    'num_posts': 12}),
#  ('curtamo',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f39')},
#    'num_datetimes': 478,
#    'num_spacy': 478,
#    'num_posts': 478}),
#  ('ladylonglegs22',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f76')},
#    'num_datetimes': 89,
#    'num_spacy': 89,
#    'num_posts': 89}),
#  ('veRGe1421',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f7a')},
#    'num_datetimes': 19,
#    'num_spacy': 19,
#    'num_posts': 19}),
#  ('maowao',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f8e')},
#    'num_datetimes': 60,
#    'num_spacy': 60,
#    'num_posts': 60}),
#  ('RustyGuns',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f95')},
#    'num_datetimes': 406,
#    'num_spacy': 406,
#    'num_posts': 406}),
#  ('Drugged_Philosopher',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13f98')},
#    'num_datetimes': 62,
#    'num_spacy': 62,
#    'num_posts': 62}),
#  ('1percentof1',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77abf4b80e41db13fa6')},
#    'num_datetimes': 250,
#    'num_spacy': 250,
#    'num_posts': 250}),
#  ('a_doh_ban',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77bbf4b80e41db13ffe')},
#    'num_datetimes': 132,
#    'num_spacy': 132,
#    'num_posts': 132}),
#  ('zebla',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77bbf4b80e41db1400b')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('patrickkevinsays',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140ba')},
#    'num_datetimes': 286,
#    'num_spacy': 286,
#    'num_posts': 286}),
#  ('thaktootsie',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140bc')},
#    'num_datetimes': 18,
#    'num_spacy': 18,
#    'num_posts': 18}),
#  ('EdwardPenishands965',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140c1')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('lambchawp',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140d1')},
#    'num_datetimes': 24,
#    'num_spacy': 24,
#    'num_posts': 24}),
#  ('ginapoppy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140d3')},
#    'num_datetimes': 367,
#    'num_spacy': 367,
#    'num_posts': 367}),
#  ('meowmeowmix',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140ec')},
#    'num_datetimes': 62,
#    'num_spacy': 62,
#    'num_posts': 62}),
#  ('forrestCLUNK',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140ef')},
#    'num_datetimes': 229,
#    'num_spacy': 229,
#    'num_posts': 229}),
#  ('WoopsRelapsed',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77cbf4b80e41db140fd')},
#    'num_datetimes': 67,
#    'num_spacy': 67,
#    'num_posts': 67}),
#  ('plzthx',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77dbf4b80e41db141a6')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('dreamboatx',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77dbf4b80e41db141b9')},
#    'num_datetimes': 156,
#    'num_spacy': 156,
#    'num_posts': 156}),
#  ('rappercake',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77dbf4b80e41db141ee')},
#    'num_datetimes': 11,
#    'num_spacy': 11,
#    'num_posts': 11}),
#  ('vinnySTAX',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14241')},
#    'num_datetimes': 27,
#    'num_spacy': 27,
#    'num_posts': 27}),
#  ('yswren',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14247')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('hats0ff',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14253')},
#    'num_datetimes': 150,
#    'num_spacy': 150,
#    'num_posts': 150}),
#  ('fillosofer',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14256')},
#    'num_datetimes': 36,
#    'num_spacy': 36,
#    'num_posts': 36}),
#  ('TheeDevinJames',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14270')},
#    'num_datetimes': 18,
#    'num_spacy': 18,
#    'num_posts': 18}),
#  ('MrNiceDye',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14272')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('frog_licker',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14275')},
#    'num_datetimes': 61,
#    'num_spacy': 61,
#    'num_posts': 61}),
#  ('StayGoldPwNyBoY',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14281')},
#    'num_datetimes': 188,
#    'num_spacy': 188,
#    'num_posts': 188}),
#  ('Lady_Ash',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db14286')},
#    'num_datetimes': 28,
#    'num_spacy': 28,
#    'num_posts': 28}),
#  ('Barsattacks',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db1428d')},
#    'num_datetimes': 51,
#    'num_spacy': 51,
#    'num_posts': 51}),
#  ('yourmomthemetalslut',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db142cb')},
#    'num_datetimes': 54,
#    'num_spacy': 54,
#    'num_posts': 54}),
#  ('interix',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db142cd')},
#    'num_datetimes': 282,
#    'num_spacy': 282,
#    'num_posts': 282}),
#  ('Warchemix',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77ebf4b80e41db142df')},
#    'num_datetimes': 30,
#    'num_spacy': 30,
#    'num_posts': 30}),
#  ('Norgetti',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77fbf4b80e41db142ff')},
#    'num_datetimes': 130,
#    'num_spacy': 130,
#    'num_posts': 130}),
#  ('Calithin',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77fbf4b80e41db1430d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('JustStopDude',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e77fbf4b80e41db14313')},
#    'num_datetimes': 261,
#    'num_spacy': 261,
#    'num_posts': 261}),
#  ('3D-Printing',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e782bf4b80e41db14547')},
#    'num_datetimes': 22,
#    'num_spacy': 22,
#    'num_posts': 22}),
#  ('1831942',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e782bf4b80e41db14573')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('OpieKid',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e782bf4b80e41db14588')},
#    'num_datetimes': 766,
#    'num_spacy': 766,
#    'num_posts': 766}),
#  ('LFerrero96',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e782bf4b80e41db145b4')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('tussinNEXT',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e782bf4b80e41db145c8')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('quantumfunk',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e782bf4b80e41db145d9')},
#    'num_datetimes': 21,
#    'num_spacy': 21,
#    'num_posts': 21}),
#  ('TheDurantula18',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e783bf4b80e41db14643')},
#    'num_datetimes': 13,
#    'num_spacy': 13,
#    'num_posts': 13}),
#  ('LK3000-',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e783bf4b80e41db14646')},
#    'num_datetimes': 30,
#    'num_spacy': 30,
#    'num_posts': 30}),
#  ('thecheezed',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e783bf4b80e41db1464d')},
#    'num_datetimes': 32,
#    'num_spacy': 32,
#    'num_posts': 32}),
#  ('blazems',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e783bf4b80e41db14659')},
#    'num_datetimes': 148,
#    'num_spacy': 148,
#    'num_posts': 148}),
#  ('Elbombshell',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e783bf4b80e41db14661')},
#    'num_datetimes': 100,
#    'num_spacy': 100,
#    'num_posts': 100}),
#  ('The_Price_Is_Right_B',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e783bf4b80e41db14663')},
#    'num_datetimes': 68,
#    'num_spacy': 68,
#    'num_posts': 68}),
#  ('PLUSsignenergy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e784bf4b80e41db146d1')},
#    'num_datetimes': 66,
#    'num_spacy': 66,
#    'num_posts': 66}),
#  ('letmehittheatm',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e786bf4b80e41db1484c')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('escobizzle',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e787bf4b80e41db14872')},
#    'num_datetimes': 277,
#    'num_spacy': 277,
#    'num_posts': 277}),
#  ('ellllie',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e787bf4b80e41db148b0')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('Mr_Bumper',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e787bf4b80e41db148b2')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('mike7260s',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e788bf4b80e41db148f1')},
#    'num_datetimes': 157,
#    'num_spacy': 157,
#    'num_posts': 157}),
#  ('xetnies',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e788bf4b80e41db1491e')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('Heemoglobin',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e789bf4b80e41db149a8')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('chrismatt999',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e789bf4b80e41db149d0')},
#    'num_datetimes': 116,
#    'num_spacy': 116,
#    'num_posts': 116}),
#  ('chinakat',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78bbf4b80e41db14a9f')},
#    'num_datetimes': 20,
#    'num_spacy': 20,
#    'num_posts': 20}),
#  ('samferrara',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78bbf4b80e41db14b03')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('oVerde',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78cbf4b80e41db14b8d')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('Infidelis45',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78cbf4b80e41db14bdb')},
#    'num_datetimes': 43,
#    'num_spacy': 43,
#    'num_posts': 43}),
#  ('earfffffffffff',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78cbf4b80e41db14bde')},
#    'num_datetimes': 72,
#    'num_spacy': 72,
#    'num_posts': 72}),
#  ('MFDdayshift',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78cbf4b80e41db14bf0')},
#    'num_datetimes': 266,
#    'num_spacy': 266,
#    'num_posts': 266}),
#  ('hillkiwi',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78cbf4b80e41db14bf4')},
#    'num_datetimes': 34,
#    'num_spacy': 34,
#    'num_posts': 34}),
#  ('kingdadrock',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78cbf4b80e41db14c31')},
#    'num_datetimes': 83,
#    'num_spacy': 83,
#    'num_posts': 83}),
#  ('bigd203',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78dbf4b80e41db14c4a')},
#    'num_datetimes': 91,
#    'num_spacy': 91,
#    'num_posts': 91}),
#  ('graspee',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78dbf4b80e41db14c4d')},
#    'num_datetimes': 21,
#    'num_spacy': 21,
#    'num_posts': 21}),
#  ('Dan0highline',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78dbf4b80e41db14c83')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Sleepthrulife',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78dbf4b80e41db14c8a')},
#    'num_datetimes': 17,
#    'num_spacy': 17,
#    'num_posts': 17}),
#  ('Shawshenk',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78dbf4b80e41db14c8c')},
#    'num_datetimes': 35,
#    'num_spacy': 35,
#    'num_posts': 35}),
#  ('DemonsNMySleep',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78dbf4b80e41db14cd3')},
#    'num_datetimes': 24,
#    'num_spacy': 24,
#    'num_posts': 24}),
#  ('moderate',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78ebf4b80e41db14ce3')},
#    'num_datetimes': 67,
#    'num_spacy': 67,
#    'num_posts': 67}),
#  ('pokepat460',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78ebf4b80e41db14cf7')},
#    'num_datetimes': 32,
#    'num_spacy': 32,
#    'num_posts': 32}),
#  ('Treadwheel',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78ebf4b80e41db14d01')},
#    'num_datetimes': 16,
#    'num_spacy': 16,
#    'num_posts': 16}),
#  ('Mookers77',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e78ebf4b80e41db14d05')},
#    'num_datetimes': 115,
#    'num_spacy': 115,
#    'num_posts': 115}),
#  ('Elrond_the_Ent',
#   {'_id': {'year': None,
#     'month': None,
# ...
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a4d8')},
#    'num_datetimes': 24,
#    'num_spacy': 24,
#    'num_posts': 24}),
#  ('ender1944',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a4f5')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('cmondude',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a505')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Brokenbones01',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a50f')},
#    'num_datetimes': 15,
#    'num_spacy': 15,
#    'num_posts': 15}),
#  ('Valentine187',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a511')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('crineumadasshit',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a513')},
#    'num_datetimes': 23,
#    'num_spacy': 23,
#    'num_posts': 23}),
#  ('Jbird206',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81abf4b80e41db1a51b')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('ChromeRadio',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81bbf4b80e41db1a5a2')},
#    'num_datetimes': 12,
#    'num_spacy': 12,
#    'num_posts': 12}),
#  ('aGreenStreetHooligan',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81cbf4b80e41db1a623')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('Structure3',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81dbf4b80e41db1a634')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Calymos',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81dbf4b80e41db1a6a9')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('RollTenTightRolls',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81ebf4b80e41db1a707')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('PeeHurt',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81ebf4b80e41db1a732')},
#    'num_datetimes': 57,
#    'num_spacy': 57,
#    'num_posts': 57}),
#  ('deepestvoice',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81ebf4b80e41db1a734')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('OneForty1',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81ebf4b80e41db1a745')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('goodkindoftragedy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81fbf4b80e41db1a7a4')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('DictatorDom14',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e81fbf4b80e41db1a7ac')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('itsandychecks',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e820bf4b80e41db1a7eb')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('nawhella',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e820bf4b80e41db1a879')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('Genuvien',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e820bf4b80e41db1a892')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('trap_god_laflare',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e821bf4b80e41db1a8a4')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('karnige',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e825bf4b80e41db1abdb')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('ejizme',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e825bf4b80e41db1ac07')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('analogjesus',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e825bf4b80e41db1ac16')},
#    'num_datetimes': 7,
#    'num_spacy': 7,
#    'num_posts': 7}),
#  ('Myrdoc',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e825bf4b80e41db1ac1d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Bacon_Donut',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e825bf4b80e41db1ac48')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('PinsNneedles',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e826bf4b80e41db1ac71')},
#    'num_datetimes': 28,
#    'num_spacy': 28,
#    'num_posts': 28}),
#  ('gabajib',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1ad6a')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('chandler608',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1ad6c')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('woodro256',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1ad7a')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('otdr42',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1ad7d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('rhysert',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1ad8c')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('thisiz923',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1adc0')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('sofcknwrong',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1adc6')},
#    'num_datetimes': 12,
#    'num_spacy': 12,
#    'num_posts': 12}),
#  ('LilCletus',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1adcf')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('defected',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1addf')},
#    'num_datetimes': 62,
#    'num_spacy': 62,
#    'num_posts': 62}),
#  ('Late_comment',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e827bf4b80e41db1adf6')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('HoChiMiner',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e829bf4b80e41db1aec7')},
#    'num_datetimes': 30,
#    'num_spacy': 30,
#    'num_posts': 30}),
#  ('sugarcoateddisease',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e829bf4b80e41db1af28')},
#    'num_datetimes': 10,
#    'num_spacy': 10,
#    'num_posts': 10}),
#  ('tactso',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e829bf4b80e41db1af3e')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('Baby-FarkMcGeezax',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82abf4b80e41db1afa3')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('Zamarok',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82abf4b80e41db1afa6')},
#    'num_datetimes': 33,
#    'num_spacy': 33,
#    'num_posts': 33}),
#  ('amandatoryy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82abf4b80e41db1aff8')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('stixy_stixy',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82bbf4b80e41db1b03d')},
#    'num_datetimes': 8,
#    'num_spacy': 8,
#    'num_posts': 8}),
#  ('patches444',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82bbf4b80e41db1b043')},
#    'num_datetimes': 19,
#    'num_spacy': 19,
#    'num_posts': 19}),
#  ('Evening_Star',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82bbf4b80e41db1b047')},
#    'num_datetimes': 17,
#    'num_spacy': 17,
#    'num_posts': 17}),
#  ('throw6539',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82bbf4b80e41db1b053')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('duncanlovesfarts',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82bbf4b80e41db1b081')},
#    'num_datetimes': 14,
#    'num_spacy': 14,
#    'num_posts': 14}),
#  ('BobOneLoveMarley',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82cbf4b80e41db1b095')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('micc117',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82cbf4b80e41db1b0b1')},
#    'num_datetimes': 128,
#    'num_spacy': 128,
#    'num_posts': 128}),
#  ('LadyCheeba',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82dbf4b80e41db1b17b')},
#    'num_datetimes': 18,
#    'num_spacy': 18,
#    'num_posts': 18}),
#  ('Bigwheel27',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82dbf4b80e41db1b181')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('heisenberg00',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82dbf4b80e41db1b18d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('russiankush',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b1a6')},
#    'num_datetimes': 11,
#    'num_spacy': 11,
#    'num_posts': 11}),
#  ('rainbowhugdancer',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b1aa')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('srock2012',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b1ba')},
#    'num_datetimes': 46,
#    'num_spacy': 46,
#    'num_posts': 46}),
#  ('kungFUPanda666',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b1c0')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('-dusk-',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b1c2')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('Rolandofthelineofeld',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b1ca')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('sleepyhouse',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82ebf4b80e41db1b210')},
#    'num_datetimes': 2,
#    'num_spacy': 2,
#    'num_posts': 2}),
#  ('OPpiates',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82fbf4b80e41db1b24f')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('footster2',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82fbf4b80e41db1b251')},
#    'num_datetimes': 25,
#    'num_spacy': 25,
#    'num_posts': 25}),
#  ('TimeTrxvel',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82fbf4b80e41db1b255')},
#    'num_datetimes': 6,
#    'num_spacy': 6,
#    'num_posts': 6}),
#  ('stevenmadden',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82fbf4b80e41db1b272')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('TheBestPlaceEver',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e82fbf4b80e41db1b277')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('ImSorryLiver',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b2c0')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('BehindOnTheTimes',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b2cf')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('L33tphreak',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b2d2')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('Aimless_Precision',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b2e4')},
#    'num_datetimes': 93,
#    'num_spacy': 93,
#    'num_posts': 93}),
#  ('CamelShakers',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b2ee')},
#    'num_datetimes': 4,
#    'num_spacy': 4,
#    'num_posts': 4}),
#  ('gidget_white',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b324')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('Oxxide',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e830bf4b80e41db1b33c')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('dijitalbus',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b36d')},
#    'num_datetimes': 42,
#    'num_spacy': 42,
#    'num_posts': 42}),
#  ('Igotdatpandemic',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b39b')},
#    'num_datetimes': 62,
#    'num_spacy': 62,
#    'num_posts': 62}),
#  ('Philanthropiss',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b39d')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('doppleherz',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b3c0')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('dittoburrito',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b3c2')},
#    'num_datetimes': 14,
#    'num_spacy': 14,
#    'num_posts': 14}),
#  ('nomoreforme02',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b3d1')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('DBlookout',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b3d6')},
#    'num_datetimes': 19,
#    'num_spacy': 19,
#    'num_posts': 19}),
#  ('count_cheska',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e831bf4b80e41db1b3d9')},
#    'num_datetimes': 93,
#    'num_spacy': 93,
#    'num_posts': 93}),
#  ('Cainepiller',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e832bf4b80e41db1b406')},
#    'num_datetimes': 14,
#    'num_spacy': 14,
#    'num_posts': 14}),
#  ('THA_COOL',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e832bf4b80e41db1b40a')},
#    'num_datetimes': 13,
#    'num_spacy': 13,
#    'num_posts': 13}),
#  ('NeedleHeadRenton',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e832bf4b80e41db1b465')},
#    'num_datetimes': 16,
#    'num_spacy': 16,
#    'num_posts': 16}),
#  ('astromechanica',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e832bf4b80e41db1b467')},
#    'num_datetimes': 22,
#    'num_spacy': 22,
#    'num_posts': 22}),
#  ('DanielStrange',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e832bf4b80e41db1b469')},
#    'num_datetimes': 5,
#    'num_spacy': 5,
#    'num_posts': 5}),
#  ('pureguavaa',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e832bf4b80e41db1b476')},
#    'num_datetimes': 9,
#    'num_spacy': 9,
#    'num_posts': 9}),
#  ('E16',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e833bf4b80e41db1b4d8')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('stalkB',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e833bf4b80e41db1b4e3')},
#    'num_datetimes': 1,
#    'num_spacy': 1,
#    'num_posts': 1}),
#  ('TribeCalledWuTang',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e833bf4b80e41db1b4f6')},
#    'num_datetimes': 45,
#    'num_spacy': 45,
#    'num_posts': 45}),
#  ('4daMaher',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e833bf4b80e41db1b50c')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ('guiltycitizen',
#   {'_id': {'year': None,
#     'month': None,
#     'user': ObjectId('5f19e833bf4b80e41db1b517')},
#    'num_datetimes': 3,
#    'num_spacy': 3,
#    'num_posts': 3}),
#  ...]

# %%
def raw_user_months_to_df(user_months):
    usernames = []
    datetimes = []
    nposts = []
    for row in user_months:
        usernames.append(row[0])
        if (row[1]['_id']['year'] and row[1]['_id']['month']):
            datetimes.append(datetime(row[1]['_id']['year'], row[1]['_id']['month'], 1))
        else:
            datetimes.append(None)
        nposts.append(row[1]['num_posts'])
    
    df = pd.DataFrame({
        'username': usernames,
        'datetime': datetimes,
        'nposts': nposts
    })
    return df

# %%
user_month_df = raw_user_months_to_df(month_users_counts)

# %%
Counter(user_month_df['datetime'])
# Out:
# Counter({NaT: 5868,
#          Timestamp('2007-08-01 00:00:00'): 4,
#          Timestamp('2007-09-01 00:00:00'): 1,
#          Timestamp('2007-10-01 00:00:00'): 1,
#          Timestamp('2007-11-01 00:00:00'): 2,
#          Timestamp('2007-12-01 00:00:00'): 2,
#          Timestamp('2008-01-01 00:00:00'): 1,
#          Timestamp('2008-03-01 00:00:00'): 3,
#          Timestamp('2008-04-01 00:00:00'): 3,
#          Timestamp('2008-05-01 00:00:00'): 7,
#          Timestamp('2008-06-01 00:00:00'): 6,
#          Timestamp('2008-07-01 00:00:00'): 4,
#          Timestamp('2008-08-01 00:00:00'): 11,
#          Timestamp('2008-09-01 00:00:00'): 28,
#          Timestamp('2008-10-01 00:00:00'): 6,
#          Timestamp('2008-11-01 00:00:00'): 12,
#          Timestamp('2008-12-01 00:00:00'): 2,
#          Timestamp('2009-03-01 00:00:00'): 3,
#          Timestamp('2009-05-01 00:00:00'): 4,
#          Timestamp('2009-06-01 00:00:00'): 2,
#          Timestamp('2009-07-01 00:00:00'): 2,
#          Timestamp('2009-08-01 00:00:00'): 12,
#          Timestamp('2009-09-01 00:00:00'): 8,
#          Timestamp('2009-10-01 00:00:00'): 4,
#          Timestamp('2009-11-01 00:00:00'): 4,
#          Timestamp('2009-12-01 00:00:00'): 5,
#          Timestamp('2010-01-01 00:00:00'): 9,
#          Timestamp('2010-02-01 00:00:00'): 12,
#          Timestamp('2010-03-01 00:00:00'): 11,
#          Timestamp('2010-04-01 00:00:00'): 9,
#          Timestamp('2010-05-01 00:00:00'): 21,
#          Timestamp('2010-06-01 00:00:00'): 36,
#          Timestamp('2010-07-01 00:00:00'): 42,
#          Timestamp('2010-08-01 00:00:00'): 42,
#          Timestamp('2010-09-01 00:00:00'): 57,
#          Timestamp('2010-10-01 00:00:00'): 36,
#          Timestamp('2010-11-01 00:00:00'): 65,
#          Timestamp('2010-12-01 00:00:00'): 59,
#          Timestamp('2011-01-01 00:00:00'): 97,
#          Timestamp('2011-02-01 00:00:00'): 75,
#          Timestamp('2011-03-01 00:00:00'): 122,
#          Timestamp('2011-04-01 00:00:00'): 79,
#          Timestamp('2011-05-01 00:00:00'): 100,
#          Timestamp('2011-06-01 00:00:00'): 117,
#          Timestamp('2011-07-01 00:00:00'): 73,
#          Timestamp('2011-08-01 00:00:00'): 70,
#          Timestamp('2011-09-01 00:00:00'): 77,
#          Timestamp('2011-10-01 00:00:00'): 108,
#          Timestamp('2011-11-01 00:00:00'): 155,
#          Timestamp('2011-12-01 00:00:00'): 241,
#          Timestamp('2012-01-01 00:00:00'): 338,
#          Timestamp('2012-02-01 00:00:00'): 464,
#          Timestamp('2012-03-01 00:00:00'): 525,
#          Timestamp('2012-04-01 00:00:00'): 628,
#          Timestamp('2012-05-01 00:00:00'): 745,
#          Timestamp('2012-06-01 00:00:00'): 745,
#          Timestamp('2012-07-01 00:00:00'): 872,
#          Timestamp('2012-08-01 00:00:00'): 790,
#          Timestamp('2012-09-01 00:00:00'): 646,
#          Timestamp('2012-10-01 00:00:00'): 731,
#          Timestamp('2012-11-01 00:00:00'): 742,
#          Timestamp('2012-12-01 00:00:00'): 828,
#          Timestamp('2013-01-01 00:00:00'): 922,
#          Timestamp('2013-02-01 00:00:00'): 882,
#          Timestamp('2013-03-01 00:00:00'): 899,
#          Timestamp('2013-04-01 00:00:00'): 965,
#          Timestamp('2013-05-01 00:00:00'): 1138,
#          Timestamp('2013-06-01 00:00:00'): 1087,
#          Timestamp('2013-07-01 00:00:00'): 1309,
#          Timestamp('2013-08-01 00:00:00'): 1333,
#          Timestamp('2013-09-01 00:00:00'): 1345,
#          Timestamp('2013-10-01 00:00:00'): 1377,
#          Timestamp('2013-11-01 00:00:00'): 1359,
#          Timestamp('2013-12-01 00:00:00'): 1515,
#          Timestamp('2014-01-01 00:00:00'): 1695,
#          Timestamp('2014-02-01 00:00:00'): 1775,
#          Timestamp('2014-03-01 00:00:00'): 1791,
#          Timestamp('2014-04-01 00:00:00'): 1748,
#          Timestamp('2014-05-01 00:00:00'): 1657,
#          Timestamp('2014-06-01 00:00:00'): 1707,
#          Timestamp('2014-07-01 00:00:00'): 1750,
#          Timestamp('2014-08-01 00:00:00'): 1706,
#          Timestamp('2014-09-01 00:00:00'): 1695,
#          Timestamp('2014-10-01 00:00:00'): 1835,
#          Timestamp('2014-11-01 00:00:00'): 1727,
#          Timestamp('2014-12-01 00:00:00'): 1790,
#          Timestamp('2015-01-01 00:00:00'): 1886,
#          Timestamp('2015-02-01 00:00:00'): 1866,
#          Timestamp('2015-03-01 00:00:00'): 1812,
#          Timestamp('2015-04-01 00:00:00'): 1870,
#          Timestamp('2015-05-01 00:00:00'): 1898,
#          Timestamp('2015-06-01 00:00:00'): 1884,
#          Timestamp('2015-07-01 00:00:00'): 1807,
#          Timestamp('2015-08-01 00:00:00'): 2146,
#          Timestamp('2015-09-01 00:00:00'): 2187,
#          Timestamp('2015-10-01 00:00:00'): 2359,
#          Timestamp('2015-11-01 00:00:00'): 2335,
#          Timestamp('2015-12-01 00:00:00'): 2523,
#          Timestamp('2016-01-01 00:00:00'): 2494,
#          Timestamp('2016-02-01 00:00:00'): 2446,
#          Timestamp('2016-03-01 00:00:00'): 2627,
#          Timestamp('2016-04-01 00:00:00'): 2523,
#          Timestamp('2016-05-01 00:00:00'): 2653,
#          Timestamp('2016-06-01 00:00:00'): 2625,
#          Timestamp('2016-07-01 00:00:00'): 2649,
#          Timestamp('2016-08-01 00:00:00'): 2863,
#          Timestamp('2016-09-01 00:00:00'): 2946,
#          Timestamp('2016-10-01 00:00:00'): 2949,
#          Timestamp('2016-11-01 00:00:00'): 3070,
#          Timestamp('2016-12-01 00:00:00'): 3198,
#          Timestamp('2017-01-01 00:00:00'): 3318,
#          Timestamp('2017-02-01 00:00:00'): 3268,
#          Timestamp('2017-03-01 00:00:00'): 3571,
#          Timestamp('2017-04-01 00:00:00'): 3492,
#          Timestamp('2017-05-01 00:00:00'): 3653,
#          Timestamp('2017-06-01 00:00:00'): 3537,
#          Timestamp('2017-07-01 00:00:00'): 3583,
#          Timestamp('2017-08-01 00:00:00'): 3903,
#          Timestamp('2017-09-01 00:00:00'): 3847,
#          Timestamp('2017-10-01 00:00:00'): 4111,
#          Timestamp('2017-11-01 00:00:00'): 4358,
#          Timestamp('2017-12-01 00:00:00'): 4306,
#          Timestamp('2018-01-01 00:00:00'): 4507,
#          Timestamp('2018-02-01 00:00:00'): 4386,
#          Timestamp('2018-03-01 00:00:00'): 5071,
#          Timestamp('2018-04-01 00:00:00'): 5151,
#          Timestamp('2018-05-01 00:00:00'): 5126,
#          Timestamp('2018-06-01 00:00:00'): 4996,
#          Timestamp('2018-07-01 00:00:00'): 5289,
#          Timestamp('2018-08-01 00:00:00'): 4902,
#          Timestamp('2018-09-01 00:00:00'): 4917,
#          Timestamp('2018-10-01 00:00:00'): 5208,
#          Timestamp('2018-11-01 00:00:00'): 5191,
#          Timestamp('2018-12-01 00:00:00'): 5463,
#          Timestamp('2019-01-01 00:00:00'): 5787,
#          Timestamp('2019-02-01 00:00:00'): 5436,
#          Timestamp('2019-03-01 00:00:00'): 5772,
#          Timestamp('2019-04-01 00:00:00'): 5596,
#          Timestamp('2019-05-01 00:00:00'): 5234,
#          Timestamp('2019-06-01 00:00:00'): 4801,
#          Timestamp('2019-07-01 00:00:00'): 4593,
#          Timestamp('2019-08-01 00:00:00'): 4419,
#          Timestamp('2019-09-01 00:00:00'): 4470,
#          Timestamp('2019-10-01 00:00:00'): 4572,
#          Timestamp('2019-11-01 00:00:00'): 4295,
#          Timestamp('2019-12-01 00:00:00'): 4807,
#          Timestamp('2020-01-01 00:00:00'): 4852,
#          Timestamp('2020-02-01 00:00:00'): 4700,
#          Timestamp('2020-03-01 00:00:00'): 4976,
#          Timestamp('2020-04-01 00:00:00'): 5358,
#          Timestamp('2020-05-01 00:00:00'): 5117,
#          Timestamp('2020-06-01 00:00:00'): 4327,
#          Timestamp('2020-07-01 00:00:00'): 4012,
#          Timestamp('2020-08-01 00:00:00'): 3982,
#          Timestamp('2020-09-01 00:00:00'): 3625,
#          Timestamp('2020-10-01 00:00:00'): 3817,
#          Timestamp('2020-11-01 00:00:00'): 3993,
#          Timestamp('2020-12-01 00:00:00'): 4156,
#          Timestamp('2021-01-01 00:00:00'): 3944,
#          Timestamp('2021-02-01 00:00:00'): 3393,
#          Timestamp('2021-03-01 00:00:00'): 2738,
#          Timestamp('2021-04-01 00:00:00'): 3742,
#          Timestamp('2021-05-01 00:00:00'): 3835,
#          Timestamp('2021-06-01 00:00:00'): 3821,
#          Timestamp('2021-07-01 00:00:00'): 3748,
#          Timestamp('2021-08-01 00:00:00'): 4037,
#          Timestamp('2021-09-01 00:00:00'): 3905})

# %%
user_month_df.groupby('datetime').count()
# Out:
#             username  nposts
# datetime
# 2007-08-01         4       4
# 2007-09-01         1       1
# 2007-10-01         1       1
# 2007-11-01         2       2
# 2007-12-01         2       2
# ...              ...     ...
# 2021-05-01      3834    3835
# 2021-06-01      3820    3821
# 2021-07-01      3747    3748
# 2021-08-01      4036    4037
# 2021-09-01      3904    3905
#
# [166 rows x 2 columns]

# %%
tf = datetime.now()
user_month_df.to_csv(f'/work/akilby/drug_pricing_project/denhart_cache/user_month_counts_df_{tf}', index=False)

# %%
user_month_df['state'] =

# %%
keyword_to_type_map = dict(zip(keywords_by_month['keywords'].tolist(), keywords_by_month['type'].tolist()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9d0017d9bbe6> in <module>
# ----> 1 keyword_to_type_map = dict(zip(keywords_by_month['keywords'].tolist(), keywords_by_month['type'].tolist()))
#
# NameError: name 'keywords_by_month' is not defined

# %%
all_keywords = list(covid_cache[list(covid_cache.keys())[0]].keys())

# %%
sample_user = list(covid_cache.keys())[0]
sample_keyword = list(covid_cache[sample_user].keys())[0]

# %%
set(keyword_to_type_map.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-80e75c07ab5f> in <module>
# ----> 1 set(keyword_to_type_map.values())
#
# NameError: name 'keyword_to_type_map' is not defined

# %%
all_months = list(covid_cache[sample_user][sample_keyword].keys())

# %%
month_keywords = []
month_months = []
month_counts = []
month_users = []
for user in tqdm(covid_cache):
    for keyword in all_keywords:
        for month in all_months:
            count = covid_cache[user][keyword][month]
            if count > 0:
                month_users.append(user)
                month_keywords.append(keyword)
                month_counts.append(count)
                month_months.append(month)
# Out:
# 100%|██████████| 64130/64130 [06:02<00:00, 176.86it/s]

# %%
len(month_keywords)
# Out:
# 1065410

# %%
opiates_df = pd.read_csv('cache/opiates_by_month_10_7.csv')

# %%
opiates_df['types'] = opiates_df.keywords.apply(lambda k: keyword_to_type_map[k] if k in keyword_to_type_map else None)

# %%
opiates_df.to_csv('opiates_counts_types.csv')

# %%
from collections import Counter

# %%
Counter(opiates_df['types'])
# Out:
# Counter({None: 658505, 'physical': 279747, 'money': 68674})

# %%
set(opiates_df)

# %%
getsizeof((month_keywords, month_counts, month_months))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1b8430750a23> in <module>
# ----> 1 getsizeof((month_keywords, month_counts, month_months))
#
# NameError: name 'getsizeof' is not defined

# %%
len(month_months)

# %%
monthly_data = {
    'keywords': month_keywords,
    'months': month_months,
    'counts': month_counts,
    'users': month_users
}

# %%
len(month_months)
# Out:
# 501

# %%
monthly_cache_fp = os.path.join(
    '/work/akilby/drug_pricing_project', 
    'denhart_cache', 
    'monthly_opiates_data_10_7_new.pk'
)
with open(monthly_cache_fp, 'wb') as f:
    pickle.dump(monthly_data, f)

# %%
with open(monthly_cache_fp, 'rb') as f:
    monthly_data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-8-9747b23021aa> in <module>
#       1 with open(monthly_cache_fp, 'rb') as f:
# ----> 2     monthly_data = pickle.load(f)
#
# EOFError: Ran out of input

# %%
getsizeof(monthly_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-b571d066b254> in <module>
# ----> 1 getsizeof(monthly_data)
#
# NameError: name 'getsizeof' is not defined

# %%
monthly_data.keys()
# Out:
# dict_keys(['keywords', 'months', 'counts', 'users'])

# %%
'payment' in monthly_data['keywords']
# Out:
# True

# %%
opiates_keywords_by_month = pd.DataFrame(monthly_data)

# %%
opiates_keywords_by_month.shape
# Out:
# (1119717, 4)

# %%
'methadone' in opiates_keywords_by_month['keywords'].tolist()
# Out:
# True

# %%
opiates_keywords_by_month.head()
# Out:
#     keywords     months  counts   users
# 0        die  (9, 2021)       2  593365
# 1  methadone  (9, 2021)       2  593365
# 2       take  (9, 2021)       2  593365
# 3     addict  (9, 2021)       1  593365
# 4       hook  (9, 2021)       1  593365

# %%
opiates_keywords_by_month.to_csv('/work/akilby/drug_pricing_project/denhart_cache/opiates_by_month_10_21.csv', index=False)

# %%
len(set(opiates_keywords_by_month['keywords']))
# Out:
# 350

# %%
opiates_keywords_by_month.head()
# Out:
#   keywords     months  counts   users      type
# 0    check  (9, 2021)       1  593365     money
# 1      try  (9, 2021)       4  593365      None
# 2      die  (9, 2021)       2  593365  physical
# 3    agree  (9, 2021)       1  593365      None
# 4     fent  (9, 2021)       2  593365      None

# %%
opiates_keywords_by_month = pd.read_csv('/work/akilby/drug_pricing_project/denhart_cache/opiates_by_month_10_4.csv')

# %%
opiates_keywords_by_month['type'] = opiates_keywords_by_month.keywords.apply(
    lambda k: keyword_to_type_map[k] if k in keyword_to_type_map else None
)

# %%
opiates_keywords_by_month
# Out:
#          keywords     months  counts         users      type
# 0           check  (9, 2021)       1        593365     money
# 1             try  (9, 2021)       4        593365      None
# 2             die  (9, 2021)       2        593365  physical
# 3           agree  (9, 2021)       1        593365      None
# 4            fent  (9, 2021)       2        593365      None
# ...           ...        ...     ...           ...       ...
# 1065405      sick  (3, 2019)       1  DeadReligion      None
# 1065406      take  (3, 2019)       3  DeadReligion      None
# 1065407  nauseous  (3, 2019)       1  DeadReligion      None
# 1065408        go  (3, 2019)       1  DeadReligion      None
# 1065409      pass  (3, 2019)       1  DeadReligion      None
#
# [1065410 rows x 5 columns]

# %%
def month_before(m) -> str:
    dt = datetime(m[1], m[0], 1)
    if ((dt.year < lockdown_dt.year) or 
        (dt.year == lockdown_dt.year and dt.month < lockdown_dt.month)):
        return 'before'
    return 'after'

# %%
opiates_keywords_by_month['period'] = opiates_keywords_by_month.months.apply(
    month_before
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a49232696ae6> in <module>
#       1 opiates_keywords_by_month['period'] = opiates_keywords_by_month.months.apply(
# ----> 2     month_before
#       3 )
#
# ~/projects/drug-pricing/.venv/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-12-06e25eb0b4cf> in month_before(m)
#       1 def month_before(m) -> str:
# ----> 2     dt = datetime(m[1], m[0], 1)
#       3     if ((dt.year < lockdown_dt.year) or
#       4         (dt.year == lockdown_dt.year and dt.month < lockdown_dt.month)):
#       5         return 'before'
#
# TypeError: an integer is required (got type str)

# %%
month_df = opiates_keywords_by_month.groupby(['months', 'keywords']).agg({
    'counts': 'sum', 
    'period': 'first',
    'type': 'first',
})

# %%
month_full_df = month_df.reset_index()

# %%
month_full_df['datetime'] = month_full_df.months.apply(lambda d: datetime(d[1], d[0], 1))

# %%
month_full_df.head()
# Out:
#       months keywords  counts  period   type   datetime
# 0  (1, 2019)  abandon      14  before   None 2019-01-01
# 1  (1, 2019)  account     234  before  money 2019-01-01
# 2  (1, 2019)   addict    1677  before   None 2019-01-01
# 3  (1, 2019)  adjourn       0  before   None 2019-01-01
# 4  (1, 2019)    agree     720  before   None 2019-01-01

# %%
addict_df = month_full_df.loc[month_full_df['keywords'] == 'addict'].sort_values('datetime')

# %%
plt.plot(addict_df['datetime'], addict_df['counts'])

# %%
month_full_df.drop('months', axis=1).to_csv('cache/keyword_month_counts_10_1.csv', index=False)

# %%
with open('cache/opiates_month_counts.pk', 'rb') as f:
    subr_counts = pickle.load(f)

# %%
subr_counts_dict = {datetime(r['_id']['year'], r['_id']['month'], 1): r['count']
                    for r in subr_counts
                    if r['_id']['month']}

# %%
subr_counts_df = pd.DataFrame.from_dict(subr_counts_dict, orient='index').reset_index()

# %%
subr_counts_df.columns = ['datetime', 'count']

# %%
subr_counts_df = subr_counts_df.sort_values('datetime')

# %%
subr_counts_df.to_csv('cache/opiates_subr_month_counts_10_1.csv', index=False)

# %%
type_df = opiates_keywords_by_month.dropna().groupby(['type', 'period']).sum()

# %%
type_df.shape
# Out:
# (4, 1)

# %%
type_df
# Out:
#                  counts
# type     period
# money    after    23832
#          before   70045
# physical after   134679
#          before  286587

# %%
g = sns.catplot(
    data=keyword_df, kind="bar",
    x="keywords", y="counts", hue="period",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Keywords")
g.legend.set_title("")
plt.xticks(rotation=45)
plt.savefig('figures/keyword_counts.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## r/opiates month counts

# %%
pk = pickle.load(open('cache/opiates_month_counts_2021-09-30 11:59:19.609911.pk', 'rb'))

# %%
ropiates_counts = []
ropiates_months = []
for r in pk:
    ropiates_counts.append(r['count'])
    if r['_id']['year']:
        ropiates_months.append(datetime(r['_id']['year'], r['_id']['month'], 1))
    else: 
        ropiates_months.append(None)

# %%
ropiates_month_counts_df = pd.DataFrame({
    'counts': ropiates_counts,
    'months': ropiates_months,
})

# %%
ropiates_month_counts_df = ropiates_month_counts_df.sort_values('months')

# %%
ropiates_month_counts_df.to_csv('/work/akilby/drug_pricing_project/denhart_cache/ropiates_counts_10_4.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(ropiates_month_counts_df.months, ropiates_month_counts_df.counts)

# %%
psaw_pk = pickle.load(open('cache/psaw_comm_month_counts_2021-09-29 06:45:51.903761.pk', 'rb'))

# %%
psaw_months = [datetime(r[1], r[0], 1) for r in psaw_pk.keys()]
psaw_counts = list(psaw_pk.values())

# %%
psaw_df = pd.DataFrame({
    'months': psaw_months,
    'counts': psaw_counts,
}).sort_values('months')

# %%
psaw_df.to_csv('/work/akilby/drug_pricing_project/denhart_cache/psaw_counts_10_4.csv')

# %%
plt.plot(psaw_df['months'], psaw_df['counts'])
plt.xticks(rotation=45)
# Out:
# (array([17775., 17897., 18017., 18140., 18262., 18383., 18506., 18628.,
#         18748., 18871.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Map Viz

# %%
users_preds = pickle.load(open('results/user-predictions-1623287814.pk', 'rb'))
